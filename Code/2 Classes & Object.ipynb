# %% [markdown]
# # Create a class Employee with attributes empid, name, salary and also define methods to access properties of Employee.

# %%
class Employee:
  def __init__(self,empid=None,name=None,salary=None):
    self.empid=empid
    self.name=name
    self.salary=salary

  def setEmpid(self,empid):
    self.empid=empid
  def setName(self,name):
    self.name=name
  def setSalary(self,salary):
    self.salary=salary

  def getEmpid(self):
    return self.empid
  def getName(self):
    return self.name
  def getSalary(self):
    return self.salary

e1 = Employee()
e2 = Employee(101,"Aman",50000)
e1.setEmpid(102)
e1.setName("John")
e1.setSalary(20000)
e3 = Employee(103,"Khonw",60000)

print(e1.getEmpid(),e1.getName(),e1.getSalary())
print(e2.getEmpid(),e2.getName(),e2.getSalary())
print(e3.getEmpid(),e3.getName(),e3.getSalary())
# Out:
# 102 John 20000
# 101 Aman 50000
# 103 Khonw 60000

# %% [markdown]
# # Define a Python class Person with instance object variables name and age. Set instance object variable in  __ init__() method. Also define show() method to disply name and age of a person.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def show(self):
        print(f"Name: {self.name}, Age: {self.age}")

p1 = Person("John", 25)
p2 = Person("Doner",19)
p3 = Person("Forera",22)
p1.show()
p2.show()
p3.show()
# Out:
# Name: John, Age: 25
# Name: Doner, Age: 19
# Name: Forera, Age: 22

# %%
class Person:
  def __init__(self,name=None,age=None):
    self.name = name
    self.age = age

  def setName(self,name):
    self.name = name
  def setAge(self,age):
    self.age = age

  def showName(self):
    return self.name
  def showAge(self):
    return self.age

p1 = Person("Honer",23)
p2 = Person("Doner",19)
p3 = Person()
print(p1.showName(),p1.showAge())
print(p2.showName(),p2.showAge())
p3.setName("Forera")
p3.setAge(12)
print(p3.showName(),p3.showAge())
# Out:
# Honer 23
# Doner 19
# Forera 12

# %% [markdown]
# # Define a class circle with instance object variable radius.provide setter and getter for radius. Also define getArea() and getCircunference() method.

# %%
import math
class Circle:
  def __init__(self,radius):
    self.radius = radius

  def setRadius(self,radius):
    self.radius = radius

  def getArea(self):
    return math.pi*self.radius**2
  def getCircumference(self):
    return 2*math.pi*self.radius

c1=Circle(58)
print(f"Area = ",c1.getArea())
print("Circumference = ",c1.getCircumference())
# Out:
# Area =  10568.317686676064 2
# Circumference =  364.424747816416

# %% [markdown]
# ## Define a class Rectangle with length and breadth as instance object variables. Provide setDimensions(), showDimensions() and getArea() method in it.

# %%
class Rectangle:
  def __init__(self,length,breadth):
    self.length = length
    self.breadth = breadth

  def setlength(self,length):
    self.length = length
  def setbreadth(self,breadth):
    self.breadth = breadth

  def showlength(self):
    return f"Length = {self.length}"
  def showbreadth(self):
    return f"Breadth = {self.breadth}"

  def getArea(self):
    return f"Area = {self.length*self.breadth}"

R = Rectangle(5,5)
print("Solution: ","\n",R.showlength(),"\n",R.showbreadth(),"\n",R.getArea())
# Out:
# Solution:
#  Length = 5
#  Breadth = 5
#  Area = 25

# %%
class Rectangle:
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def setDimensions(self, length, breadth):
        self.length = length
        self.breadth = breadth

    def showDimensions(self):
        print("Length:", self.length)
        print("Breadth:", self.breadth)

    def getArea(self):
        return self.length * self.breadth

# Example usage:
rectangle = Rectangle(5, 4)
rectangle.showDimensions()
print("Area:", rectangle.getArea())

# Modify dimensions
rectangle.setDimensions(7, 3)
rectangle.showDimensions()
print("Area:", rectangle.getArea())
# Out:
# Length: 5
# Breadth: 4
# Area: 20
# Length: 7
# Breadth: 3
# Area: 21

# %% [markdown]
# ## Define a class Book with instance object variable bookid, title and price. Initialise them via   __ init__() method. Also define method to show book variables.

# %%
class Book:
  def __init__(self, bookid, title, author, price):
    self.bookid = bookid
    self.title = title
    self.author = author
    self.price = price

  def setBook(self,bookid,title,author,price):
    self.bookid = bookid
    self.title = title
    self.author = author
    self.price = price

  def showBook(self):
    print("Book ID - ",self.bookid)
    print("Title - ",self.title)
    print("Author - ",self.author)
    print("Price - ",self.price)

  def getbookid(self):
    return self.bookid

  def gettitle(self):
    return self.title

  def getauthor(self):
    return self.author

  def getprice(self):
    return self.price

B1 = Book(2024101,"Four Stars of Destiny","General Manoj Mukund Naravane",1551)
B2 = Book(2024102,"Ram Mandir Rashtra Mandir Ek Sajhi Virast","Geeta Singh and Arif Khan Bharti",789)
B3 = Book(2024103,"The Bill Gates Notes","Bill Gates",699)
B4 = Book(2024104,"Why India Matter","Dr. S. Jayshankar",999)
B5 = Book(2024105,"The Man Behind the Uniform","Rachna Biswat Rawat",564)
B6 = Book(2023106,"India’s vaccine Growth story","Sajjan singh Dev",450)
B7 = Book(2021107,"400 Days","Chetan Bhagat",400)
B8 = Book(2018108,"Changing India","Dr. Manmohan Singh",785)
B9 = Book(2018109,"Why I am hindu","Shashi Tharoor",101)
B10 = Book(2018110,"Indian Cultures as Heritage: Contemporary Pasts","Romila Thapar",269)
# B2.setBook(2024102,"Ram Mandir Rashtra Mandir Ek Sajhi Virast","Geeta Singh and Arif Khan Bharti",789)

# print(B1.getBook())

print(B1.getbookid(),B1.gettitle(),B1.getauthor(),B1.getprice())
print(B2.getbookid(),B2.gettitle(),B2.getauthor(),B2.getprice())
print(B3.getbookid(),B3.gettitle(),B3.getauthor(),B3.getprice())
print(B4.getbookid(),B4.gettitle(),B4.getauthor(),B4.getprice())
print(B5.getbookid(),B5.gettitle(),B5.getauthor(),B5.getprice())
print(B6.getbookid(),B6.gettitle(),B6.getauthor(),B6.getprice())
print(B7.getbookid(),B7.gettitle(),B7.getauthor(),B7.getprice())
print(B8.getbookid(),B8.gettitle(),B8.getauthor(),B8.getprice())
print(B9.getbookid(),B9.gettitle(),B9.getauthor(),B9.getprice())
print(B10.getbookid(),B10.gettitle(),B10.getauthor(),B10.getprice())
# Out:
# 2024101 Four Stars of Destiny General Manoj Mukund Naravane 1551
# 2024102 Ram Mandir Rashtra Mandir Ek Sajhi Virast Geeta Singh and Arif Khan Bharti 789
# 2024103 The Bill Gates Notes Bill Gates 699
# 2024104 Why India Matter Dr. S. Jayshankar 999
# 2024105 The Man Behind the Uniform Rachna Biswat Rawat 564
# 2023106 India’s vaccine Growth story Sajjan singh Dev 450
# 2021107 400 Days Chetan Bhagat 400
# 2018108 Changing India Dr. Manmohan Singh 785
# 2018109 Why I am hindu Shashi Tharoor 101
# 2018110 Indian Cultures as Heritage: Contemporary Pasts Romila Thapar 269

# %%
from tabulate import tabulate

class Book:
    def __init__(self, bookid, title, author, price):
        self.bookid = bookid
        self.title = title
        self.author = author
        self.price = price

    def setBook(self, bookid, title, author, price):
        self.bookid = bookid
        self.title = title
        self.author = author
        self.price = price

    def showBook(self):
        return [self.bookid, self.title, self.author, self.price]

B1 = Book(2024101,"Four Stars of Destiny","General Manoj Mukund Naravane",1551)
B2 = Book(2024102,"Ram Mandir Rashtra Mandir Ek Sajhi Virast","Geeta Singh and Arif Khan Bharti",789)
B3 = Book(2024103,"The Bill Gates Notes","Bill Gates",699)
B4 = Book(2024104,"Why India Matter","Dr. S. Jayshankar",999)
B5 = Book(2024105,"The Man Behind the Uniform","Rachna Biswat Rawat",564)
B6 = Book(2023106,"India’s vaccine Growth story","Sajjan singh Dev",450)
B7 = Book(2021107,"400 Days","Chetan Bhagat",400)
B8 = Book(2018108,"Changing India","Dr. Manmohan Singh",785)
B9 = Book(2018109,"Why I am hindu","Shashi Tharoor",101)
B10 = Book(2018110,"Indian Cultures as Heritage: Contemporary Pasts","Romila Thapar",269)

books_data = []
for book in [B1, B2, B3, B4, B5, B6, B7, B8, B9, B10]:
    books_data.append(book.showBook())

headers = ["Book ID", "Title", "Author", "Price"]
print(tabulate(books_data, headers=headers, tablefmt="grid"))
# Out:
# +-----------+-------------------------------------------------+----------------------------------+---------+
# |   Book ID | Title                                           | Author                           |   Price |
# +===========+=================================================+==================================+=========+
# |   2024101 | Four Stars of Destiny                           | General Manoj Mukund Naravane    |    1551 |
# +-----------+-------------------------------------------------+----------------------------------+---------+
# |   2024102 | Ram Mandir Rashtra Mandir Ek Sajhi Virast       | Geeta Singh and Arif Khan Bharti |     789 |
# +-----------+-------------------------------------------------+----------------------------------+---------+
# |   2024103 | The Bill Gates Notes                            | Bill Gates                       |     699 |
# +-----------+-------------------------------------------------+----------------------------------+---------+
# ...

# %% [markdown]
# ## Define a class Team with instance object variable a list of team member names. Provide methods to input member names and display member names.

# %%
class Team:
  def __init__(self,name):
    self.name = name

  def setName(self,name):
    self.name = name

  def showName(self):
    return self.name

t1 = Team("Alok")
t1.showName()
# Out:
# 'Alok'

# %%
class Team:
  def __init__(self):
    self.members = []

  def inputMembers(self):
    num_members = int(input("Enter the number of group member: "))
    for i in range(num_members):
            member_name = input(f"Enter name of team member {i+1}: ")
            self.members.append(member_name)

  def displayMembers(self):
        print("Team Members:")
        for member in self.members:
            print(member)

team = Team()
team.inputMembers()
team.displayMembers()
# Out:
# Enter the number of group member: 5
# Enter name of team member 1: Alok Kumar Choudhary
# Enter name of team member 2: Swetankan Shinha
# Enter name of team member 3: Rohit Kumar
# Enter name of team member 4: Shadab Mustaque
# Enter name of team member 5: Shitika
# Team Members:
# Alok Kumar Choudhary
# Swetankan Shinha
# Rohit Kumar
# Shadab Mustaque
# Shitika
